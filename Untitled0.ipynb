# %% [markdown]
# <a href="https://colab.research.google.com/github/enen1114/algorithms-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
year = int(input("請輸入一個年份:"))
if (year % 4) == 0:
  if (year % 100) == 0:
    if (year % 400) == 0:
      print("{0} 是潤年".format(year))   # 百年並且能被400整除的是潤年
elif year % 400 == 0:        
  print("{0} 是潤年".format(year))   # 不是百年能被4整除的是潤年
else:
  print('平年')
# Out:
# 請輸入一個年份:1991
# 平年

# %%
year = [2000,2004,2008,2012,2016,2020,2024,2028,2032,2036,2040]
y = int(input("請輸入2000-2040的年份:"))
if y in year :
  print("%s是潤年" %y) 
else:
  print("%s不是潤年" %y)
# Out:
# 請輸入2000-2040的年份:2000
# 2000是潤年
